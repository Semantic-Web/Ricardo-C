# %%
# %matplotlib inline
from __future__ import division
from datetime import datetime
from datetime import timedelta
import tabulate
import operator
import matplotlib.pyplot as plt
from collections import defaultdict
#importing modules

# %%
#This function takes our source data array and calculates the percentage of time spent on each activity over the 14 days
def aggregateAvg(array):

    dates = []
    activities = []
    d = timedelta(days=14).total_seconds()


    for row in range(2,len(array)):
        t1 = datetime.strptime(array[row][1], "%Y-%m-%d %H:%M:%S")
        t2 = datetime.strptime(array[row][0], "%Y-%m-%d %H:%M:%S")

        difference = t1 - t2


        dates.append(difference.total_seconds())
        activities.append(array[row][2])

    tups = zip(activities,dates)

    dict = defaultdict(float)
    for (act, dat) in tups:
        dict[act] +=(dat)/d


    return dict

# %%
#This function aggregates the duration for the activties so that we can see total time spentt for each of them
def aggregateDates(array):

    dates = []
    activities = []


    for row in range(2,len(array)):
        t1 = datetime.strptime(array[row][1], "%Y-%m-%d %H:%M:%S")
        t2 = datetime.strptime(array[row][0], "%Y-%m-%d %H:%M:%S")

        difference = t1 - t2


        dates.append(difference)
        activities.append(array[row][2])

    tups = zip(activities,dates)

    dict = defaultdict(timedelta)
    for (act, dat) in tups:
        dict[act] += dat


    return dict

# %%
#This function calculates activity totals per activity
def activityDuration(array):

    totals = []
    x = 0
    for row in range(2,len(array)):
        t1 = datetime.strptime(array[row][1], "%Y-%m-%d %H:%M:%S")
        t2 = datetime.strptime(array[row][0], "%Y-%m-%d %H:%M:%S")

        difference = t1 - t2

        totals.append([])
        totals[x].append(difference)
        totals[x].append(array[row][2])

        x+=1

    return totals

# %%
#The following functions simply pretty print the data using tabulate
def printCumTotals(dict):

    table = []
    table.append(dict)

    print("\nCumulative time spent on activities over 14 days\n\n")
    print tabulate.tabulate(table, headers="keys")

def printAverages(dict):

    table = []
    table.append(dict)

    print("\nPercent of time spent on activities over 14 days")
    print tabulate.tabulate(table, headers="keys")



def printActivityTotals(array):


    print ("Time Spent Per Activity Instance\n\n")
    print tabulate.tabulate(array, headers=["Time Spent","Activity"])

# %%
#The following function opens and parses our source file.
def read_file():
    source = []
    with open('data.csv') as data:
        for line in data:
            source.append(line.strip().split('\t\t'))

    return source

# %%
#The following function plots our data
def drawChart(dict):

    values  = sorted(dict.items(), key=operator.itemgetter(1))


    y_val = [i[1] for i in values]
    xticks = [i[0] for i in values]

    x_val = [20,40,60,80,100,120,140,160,180]
    plt.bar(x_val,y_val,10)
    plt.xticks(x_val,xticks,fontsize=10, rotation='vertical' )
    plt.xlabel('Activity')
    plt.ylabel('Percent of time Spent')
    plt.title('Percent of Time Spent on Activities')
    plt.grid(True)
    plt.show()

# %%
#defining and calling main method
def main():

    l = []
    #f = open(sys.argv[1], 'rU')
    with open('data.csv') as data:
        for line in data:
            l.append(line.strip().split('\t\t'))

    totals = activityDuration(l)
    printActivityTotals(totals)

    dict = aggregateDates(l)

    printCumTotals(dict)

    avgdict= aggregateAvg(l)
    printAverages(avgdict)

    drawChart(avgdict)


main()
# Out:
# Time Spent Per Activity Instance
#
#
# Time Spent    Activity
# ------------  -------------
# 7:50:12       Sleeping
# 0:02:12       Toileting
# 0:07:16       Showering
# 0:08:37       Breakfast
# 0:01:25       Grooming
# 2:13:26       Spare_Time/TV
# 0:00:27       Toileting
# 0:19:38       Leaving
# 0:43:00       Spare_Time/TV
# 0:04:29       Toileting
# 0:36:49       Lunch
# 0:01:30       Grooming
# 5:12:59       Spare_Time/TV
# 0:00:04       Snack
# 5:44:45       Spare_Time/TV
# 9:15:00       Sleeping
# 0:05:00       Toileting
# 0:11:16       Grooming
# 0:01:16       Showering
# 0:09:32       Breakfast
# 0:02:59       Grooming
# 0:02:21       Spare_Time/TV
# 0:00:03       Snack
# 1:46:48       Spare_Time/TV
# 0:00:29       Toileting
# 0:31:21       Lunch
# 0:01:03       Grooming
# 0:25:54       Spare_Time/TV
# 0:13:27       Toileting
# 0:33:50       Spare_Time/TV
# 0:00:31       Toileting
# 1:14:22       Spare_Time/TV
# 1:21:23       Leaving
# 4:51:47       Spare_Time/TV
# 8:44:58       Sleeping
# 0:02:52       Toileting
# 0:03:48       Showering
# 0:12:01       Breakfast
# 0:01:43       Grooming
# 2:23:21       Spare_Time/TV
# 0:00:04       Snack
# 1:03:56       Spare_Time/TV
# 0:00:32       Toileting
# 0:20:24       Spare_Time/TV
# 0:20:42       Lunch
# 1:27:23       Spare_Time/TV
# 0:00:23       Toileting
# 0:00:04       Snack
# 1:19:23       Spare_Time/TV
# 0:00:03       Toileting
# 0:41:26       Spare_Time/TV
# 0:00:26       Toileting
# 0:39:31       Spare_Time/TV
# 0:00:25       Toileting
# 0:18:28       Leaving
# 0:00:09       Grooming
# 5:20:24       Spare_Time/TV
# 9:12:53       Sleeping
# 0:00:29       Grooming
# 0:13:45       Showering
# 0:12:44       Breakfast
# 2:58:56       Spare_Time/TV
# 0:25:25       Lunch
# 1:17:17       Spare_Time/TV
# 0:00:29       Toileting
# 0:19:37       Spare_Time/TV
# 0:09:50       Grooming
# 0:15:31       Spare_Time/TV
# 4:22:51       Spare_Time/TV
# 0:00:28       Grooming
# 1:24:00       Spare_Time/TV
# 0:00:13       Grooming
# 0:49:08       Spare_Time/TV
# 0:04:23       Grooming
# 9:59:24       Sleeping
# 0:04:40       Toileting
# 0:04:21       Showering
# 2:08:42       Spare_Time/TV
# 0:33:00       Lunch
# 0:31:07       Spare_Time/TV
# 0:01:53       Grooming
# 0:38:05       Spare_Time/TV
# 0:10:00       Toileting
# 2:51:29       Spare_Time/TV
# 0:00:06       Snack
# 1:44:55       Spare_Time/TV
# 0:17:28       Toileting
# 3:54:37       Spare_Time/TV
# 10:09:18      Sleeping
# 0:02:00       Toileting
# 0:02:26       Grooming
# 0:03:50       Showering
# 0:08:55       Breakfast
# 1:07:06       Spare_Time/TV
# 0:00:59       Grooming
# 0:31:32       Spare_Time/TV
# 0:03:33       Grooming
# 3:30:26       Leaving
# 6:03:10       Spare_Time/TV
# 0:00:51       Toileting
# 3:20:55       Spare_Time/TV
# 9:18:32       Sleeping
# 0:05:59       Toileting
# 0:01:17       Grooming
# 0:03:59       Showering
# 0:03:40       Breakfast
# 0:57:17       Spare_Time/TV
# 0:03:30       Toileting
# 2:19:11       Leaving
# 0:51:39       Spare_Time/TV
# 0:00:05       Snack
# 0:16:40       Spare_Time/TV
# 0:00:59       Grooming
# 0:49:24       Spare_Time/TV
# 0:01:27       Toileting
# 0:00:06       Snack
# 3:20:55       Spare_Time/TV
# 0:01:00       Toileting
# 3:05:50       Spare_Time/TV
# 0:00:05       Grooming
# 10:13:45      Sleeping
# 0:00:30       Toileting
# 0:00:08       Grooming
# 0:07:33       Showering
# 0:09:48       Breakfast
# 0:40:17       Spare_Time/TV
# 0:00:06       Grooming
# 0:16:59       Leaving
# 0:43:08       Lunch
# 0:01:34       Grooming
# 0:00:16       Toileting
# 0:17:14       Spare_Time/TV
# 0:30:00       Toileting
# 0:37:17       Spare_Time/TV
# 1:40:09       Leaving
# 0:22:20       Spare_Time/TV
# 0:00:05       Snack
# 0:42:57       Spare_Time/TV
# 0:00:15       Grooming
# 0:00:40       Toileting
# 0:57:25       Spare_Time/TV
# 0:00:08       Toileting
# 0:00:16       Grooming
# 3:31:10       Spare_Time/TV
# 0:01:40       Toileting
# 9:24:43       Sleeping
# 0:00:53       Toileting
# 0:01:56       Grooming
# 0:13:38       Showering
# 0:05:07       Breakfast
# 2:58:16       Spare_Time/TV
# 0:35:05       Lunch
# 0:01:57       Grooming
# 1:49:18       Spare_Time/TV
# 0:06:00       Toileting
# 0:46:52       Spare_Time/TV
# 0:00:12       Grooming
# 1:14:57       Spare_Time/TV
# 0:00:05       Snack
# 0:00:24       Grooming
# 4:27:10       Spare_Time/TV
# 0:00:10       Grooming
# 0:46:40       Spare_Time/TV
# 0:00:24       Toileting
# 9:45:44       Sleeping
# 0:03:11       Toileting
# 0:13:41       Grooming
# 0:05:41       Showering
# 0:07:47       Breakfast
# 2:33:12       Spare_Time/TV
# 0:35:56       Lunch
# 0:46:04       Spare_Time/TV
# 0:00:18       Grooming
# 0:00:04       Toileting
# 0:39:13       Spare_Time/TV
# 0:05:43       Grooming
# 1:46:51       Leaving
# 0:00:03       Grooming
# 0:00:03       Toileting
# 1:05:55       Spare_Time/TV
# 0:04:51       Snack
# 0:00:28       Snack
# 0:00:28       Toileting
# 0:02:06       Spare_Time/TV
# 2:27:07       Spare_Time/TV
# 0:00:16       Toileting
# 2:12:16       Spare_Time/TV
# 9:34:48       Sleeping
# 0:00:11       Grooming
# 0:00:09       Toileting
# 0:00:11       Grooming
# 0:04:55       Showering
# 0:08:49       Breakfast
# 2:05:10       Spare_Time/TV
# 0:00:12       Grooming
# 2:11:38       Leaving
# 5:48:56       Spare_Time/TV
# 0:00:14       Grooming
# 0:58:23       Spare_Time/TV
# 0:00:18       Grooming
# 1:48:32       Spare_Time/TV
# 0:01:19       Grooming
# 9:32:25       Sleeping
# 0:00:31       Toileting
# 0:00:20       Grooming
# 0:03:23       Showering
# 0:08:02       Breakfast
# 1:23:22       Spare_Time/TV
# 0:08:54       Grooming
# 3:49:40       Leaving
# 0:13:59       Spare_Time/TV
# 0:03:20       Toileting
# 0:52:41       Spare_Time/TV
# 0:00:02       Grooming
# 0:16:45       Spare_Time/TV
# 0:16:34       Leaving
# 1:44:37       Spare_Time/TV
# 0:00:13       Grooming
# 3:11:22       Spare_Time/TV
# 0:00:18       Grooming
# 0:29:08       Spare_Time/TV
# 8:35:30       Sleeping
# 0:07:48       Toileting
# 0:09:11       Grooming
# 0:04:58       Showering
# 0:06:52       Breakfast
# 2:30:49       Spare_Time/TV
# 0:00:45       Grooming
# 4:03:00       Leaving
# 3:05:28       Spare_Time/TV
# 0:01:22       Grooming
# 4:30:25       Leaving
# 1:24:48       Spare_Time/TV
# 0:01:21       Grooming
# 9:26:19       Sleeping
# 0:03:10       Toileting
# 0:00:14       Grooming
# 0:15:46       Showering
# 0:08:12       Breakfast
# 1:53:29       Spare_Time/TV
# 0:52:05       Lunch
# 0:01:15       Toileting
# 0:01:56       Grooming
# 5:57:57       Spare_Time/TV
#
# Cumulative time spent on activities over 14 days
#
#
# Toileting    Showering    Spare_Time/TV     Sleeping          Lunch    Snack    Breakfast    Leaving         Grooming
# -----------  -----------  ----------------  ----------------  -------  -------  -----------  --------------  ----------
# 2:19:26      1:34:09      5 days, 22:28:55  5 days, 11:03:31  5:13:31  0:06:01  1:50:06      1 day, 2:24:22  1:40:24
#
# Percent of time spent on activities over 14 days
#   Toileting    Showering    Spare_Time/TV    Sleeping      Lunch        Snack    Breakfast    Leaving    Grooming
# -----------  -----------  ---------------  ----------  ---------  -----------  -----------  ---------  ----------
#  0.00691634   0.00467014         0.424053    0.390055  0.0155514  0.000298446   0.00546131  0.0785896  0.00498016
